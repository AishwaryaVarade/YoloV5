# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5 
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.8.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/'cifar10_file'/
# Out:
# 4/1AY0e-g4k_zdGAbujhED3dlKqQc5Hk418DqFEY4b2SmKRi4hDBHBH91It27w 4d20.jpg			       dog-and-cat-cover.jpg
# 'Copy of IMAGE CLASSIFICATION.ipynb'   dog-puppy.jpg
#  Data_Scrap_TestT		       dogs-and-cats.jpg
#  Data_Scrap_Test.zip		       download.jpg
#  Data_Scrap_Train1		       image_dataset.yaml
#  Data_Scrap_Trainn		       my-dog-frog.jpg
#  Data_Scrap_Train.zip		       old_Data_Scrap_Test.zip

# %%
# !unzip -q /content/drive/MyDrive/'cifar10_file'/Data_Scrap_Test.zip -d ../

# %%
#Copying Yaml File to Yolov5
# %cp /content/drive/MyDrive/'cifar10_file'/image_dataset.yaml /content/yolov5/models/

# %%
# !python train.py --img 540 --batch 16 --epochs 500 --data image_dataset.yaml --weights yolov5s.pt --nosave --cache
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Total 5 (delta 4), reused 4 (delta 4), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/ultralytics/yolov5
#    407dc50..aad99b6  master     -> origin/master
# github: ⚠️ WARNING: code is out of date by 1 commit. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
from IPython.display import Image, clear_output , VimeoVideo # to display images

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/exp2/test_batch1_pred.jpg', width=1000)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.5 --source /content/Data_Scrap_Test/airplane1.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/Data_Scrap_Test/airplane1.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-112-g9f3a388 torch 1.8.1+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/Data_Scrap_Test/airplane1.jpg: 448x640 1 airplane, Done. (0.034s)
# Results saved to runs/detect/exp2
# Done. (0.050s)

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/cifar10_file/dogs-and-cats.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/dogs-and-cats.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/dogs-and-cats.jpg: 288x640 1 cat, 1 dog, Done. (0.010s)
# Results saved to runs/detect/exp6
# Done. (0.027s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp/dogs-and-cats.jpg', width=500)
# Out:
# Manual Image:

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/cifar10_file/dog-and-cat-cover.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/dog-and-cat-cover.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/dog-and-cat-cover.jpg: 352x640 1 cat, 1 dog, Done. (0.010s)
# Results saved to runs/detect/exp7
# Done. (0.035s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp2/dog-and-cat-cover.jpg', width=600)
# Out:
# Manual Image:

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/cifar10_file/my-dog-frog.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/my-dog-frog.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/my-dog-frog.jpg: 352x640 1 dog, 1 frog, Done. (0.010s)
# Results saved to runs/detect/exp8
# Done. (0.039s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp8/my-dog-frog.jpg', width=600)
# Out:
# Manual Image:

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/cifar10_file/dog-puppy.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/dog-puppy.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/dog-puppy.jpg: 352x640 1 dog, Done. (0.010s)
# Results saved to runs/detect/exp9
# Done. (0.039s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp6/dog-puppy.jpg', width=600)
# Out:
# Manual Image:

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/cifar10_file/download.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/download.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/download.jpg: 352x640 1 airplane, 1 ship, Done. (0.010s)
# Results saved to runs/detect/exp22
# Done. (0.017s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp22/download.jpg', width=800)
# Out:
# Manual Image:

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.2 --source /content/drive/MyDrive/cifar10_file/big-cruise-ship-and-plane.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/big-cruise-ship-and-plane.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/big-cruise-ship-and-plane.jpg: 448x640 1 airplane, 1 ship, Done. (0.011s)
# Results saved to runs/detect/exp20
# Done. (0.054s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp20/big-cruise-ship-and-plane.jpg', width=600)
# Out:
# Manual Image:

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/cifar10_file/ship-airplane.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/cifar10_file/ship-airplane.jpg', update=False, view_img=False, weights=['runs/train/exp2/weights/last.pt'])
# YOLOv5 🚀 v5.0-115-g407dc50 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7078183 parameters, 0 gradients, 16.4 GFLOPS
# image 1/1 /content/drive/MyDrive/cifar10_file/ship-airplane.jpg: 480x640 1 airplane, 1 ship, Done. (0.011s)
# Results saved to runs/detect/exp23
# Done. (0.390s)

# %%
print("Manual Image:")
Image(filename='/content/yolov5/runs/detect/exp23/ship-airplane.jpg', width=600)
# Out:
# Manual Image:
